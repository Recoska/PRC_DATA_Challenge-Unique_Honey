# %%
import pandas as pd

from pathlib import Path
import os

# Load data - fuel_train includes fuel consumption in segments
DATA_ORIGIN = Path("data")
PATH = os.path.join(DATA_ORIGIN, "flights_train")
# === CONFIG ===
DATA_DIR = Path(PATH) # <- change this
COLUMNS = ["timestamp",
           "longitude", "latitude",
           "altitude", "groundspeed",
           "track", "vertical_rate"]


def load_all_parquet(dir_path: Path) -> pd.DataFrame:
    """
    Read all parquet files in a folder, keep only relevant columns,
    and concatenate into a single pandas DataFrame.
    """
    dfs = []
    files = sorted(dir_path.glob("*.parquet"))

    if not files:
        raise FileNotFoundError(f"No .parquet files found in {dir_path}")

    for f in files:
        print(f"Reading {f.name} ...")
        df = pd.read_parquet(f)

        # keep only columns we care about if they exist
        missing = [c for c in COLUMNS if c not in df.columns]
        if missing:
            print(f"  -> skipping {f.name}, missing columns: {missing}")
            continue

        df = df[COLUMNS].copy()
        dfs.append(df)

    if not dfs:
        raise ValueError("No usable parquet files found (all missing required columns).")

    df_all = pd.concat(dfs, ignore_index=True)

    # ensure timestamp is datetime
    df_all["timestamp"] = pd.to_datetime(df_all["timestamp"])

    return df_all

import numpy as np
import matplotlib.pyplot as plt

def plot_distributions(df: pd.DataFrame):
    """
    Plot 1D distributions (histograms) for all numeric flight variables,
    with y-axis showing percentage of samples instead of raw counts.
    """
    vars_num = ["longitude", "latitude", "altitude",
                "groundspeed", "track", "vertical_rate"]

    for col in vars_num:
        data = df[col].dropna().values

        if data.size == 0:
            print(f"Skipping {col}: no non-NA values.")
            continue

        # weights so that the sum of all bins = 100 (%)
        weights = np.ones_like(data, dtype=float) / data.size * 100.0

        plt.figure(figsize=(8, 4))
        plt.hist(data, bins=200, weights=weights)
        plt.title(f"Histogram of {col}")
        plt.xlabel(col)
        plt.ylabel("Percentage of samples [%]")
        plt.tight_layout()
        plt.show()



def plot_timestamp_series(df: pd.DataFrame, max_points: int = 500_000):
    """
    Time-series style plots: variable vs timestamp.

    To avoid over-plotting / memory issues, downsample if there are
    more than `max_points` rows.
    """
    df_ts = df.sort_values("timestamp")

    n = len(df_ts)
    if n > max_points:
        step = max(n // max_points, 1)
        df_ts = df_ts.iloc[::step]
        print(f"Downsampled time-series from {n} to {len(df_ts)} points for plotting.")

    vars_num = ["altitude", "groundspeed", "vertical_rate"]
    for col in vars_num:
        plt.figure(figsize=(12, 4))
        plt.plot(df_ts["timestamp"], df_ts[col], linewidth=0.5)
        plt.title(f"{col} over time (all flights)")
        plt.xlabel("timestamp")
        plt.ylabel(col)
        plt.tight_layout()
        plt.show()


def plot_extra_helpful(df: pd.DataFrame):
    """
    A few extra plots that are typically useful:
      - Lat vs Lon scatter: rough flight map
      - Altitude vs Groundspeed 2D scatter
      - Altitude vs Vertical rate 2D scatter
    """
    # Lat/Lon scatter (very useful to see coverage + obvious outliers)
    plt.figure(figsize=(6, 6))
    plt.scatter(df["longitude"], df["latitude"], s=1, alpha=0.1)
    plt.xlabel("longitude")
    plt.ylabel("latitude")
    plt.title("Longitude vs Latitude (all flights)")
    plt.tight_layout()
    plt.show()

    # Altitude vs Groundspeed
    plt.figure(figsize=(6, 4))
    plt.scatter(df["groundspeed"], df["altitude"], s=1, alpha=0.1)
    plt.xlabel("groundspeed [kt]")
    plt.ylabel("altitude [ft]")
    plt.title("Altitude vs Groundspeed")
    plt.tight_layout()
    plt.show()

    # Altitude vs Vertical Rate
    if df["vertical_rate"].notna().any():
        plt.figure(figsize=(6, 4))
        plt.scatter(df["vertical_rate"], df["altitude"], s=1, alpha=0.1)
        plt.xlabel("vertical_rate [ft/min?]")
        plt.ylabel("altitude [ft]")
        plt.title("Altitude vs Vertical Rate")
        plt.tight_layout()
        plt.show()


def main():
    # 1) load and merge all parquet files
    df_all = load_all_parquet(DATA_DIR)

    # quick numeric summary
    print("\n=== Summary statistics ===")
    print(df_all[["longitude", "latitude",
                  "altitude", "groundspeed",
                  "track", "vertical_rate"]].describe(
                      percentiles=[0.01, 0.05, 0.5, 0.95, 0.99]
                  ))

    # 2) distribution plots
    plot_distributions(df_all)

    # 3) timestamp-based plots
    plot_timestamp_series(df_all)

    # 4) extra helpful plots
    plot_extra_helpful(df_all)


if __name__ == "__main__":
    main()
# Out:
# Reading prc770822360.parquet ...
# Reading prc770831136.parquet ...
# Reading prc770835414.parquet ...
# Reading prc770844923.parquet ...
# Reading prc770847190.parquet ...
# Reading prc770852254.parquet ...
# Reading prc770853645.parquet ...
# Reading prc770859206.parquet ...
# Reading prc770860078.parquet ...
# Reading prc770864956.parquet ...
# Reading prc770866486.parquet ...
# Reading prc770867379.parquet ...
# Reading prc770868424.parquet ...
# Reading prc770870642.parquet ...
# Reading prc770872129.parquet ...
# Reading prc770875579.parquet ...
# Reading prc770876146.parquet ...
# Reading prc770876159.parquet ...
# Reading prc770876744.parquet ...
# Reading prc770878608.parquet ...
# Reading prc770879349.parquet ...
# Reading prc770881363.parquet ...
# Reading prc770882585.parquet ...
# Reading prc770882767.parquet ...
# Reading prc770885136.parquet ...
# Reading prc770887177.parquet ...
# Reading prc770887278.parquet ...
# Reading prc770887555.parquet ...
# Reading prc770887933.parquet ...
# Reading prc770888915.parquet ...
# Reading prc770893597.parquet ...
# Reading prc770894018.parquet ...
# Reading prc770896208.parquet ...
# Reading prc770897620.parquet ...
# Reading prc770900396.parquet ...
# Reading prc770900987.parquet ...
# Reading prc770901870.parquet ...
# Reading prc770903249.parquet ...
# Reading prc770904659.parquet ...
# Reading prc770905008.parquet ...
# Reading prc770906482.parquet ...
# Reading prc770907139.parquet ...
# Reading prc770908304.parquet ...
# Reading prc770909580.parquet ...
# Reading prc770909644.parquet ...
# Reading prc770912173.parquet ...
# Reading prc770912944.parquet ...
# Reading prc770914339.parquet ...
# Reading prc770914366.parquet ...
# Reading prc770914657.parquet ...
# Reading prc770917945.parquet ...
# Reading prc770919451.parquet ...
# Reading prc770919850.parquet ...
# Reading prc770920259.parquet ...
# Reading prc771439034.parquet ...
# Reading prc771439429.parquet ...
# Reading prc771439432.parquet ...
# Reading prc771440057.parquet ...
# Reading prc771443423.parquet ...
# Reading prc771445817.parquet ...
# Reading prc771446967.parquet ...
# Reading prc771447665.parquet ...
# Reading prc771451060.parquet ...
# Reading prc771451735.parquet ...
# Reading prc771452788.parquet ...
# Reading prc771453977.parquet ...
# Reading prc771457042.parquet ...
# Reading prc771457439.parquet ...
# Reading prc771461678.parquet ...
# Reading prc771461737.parquet ...
# Reading prc771464998.parquet ...
# Reading prc771465006.parquet ...
# Reading prc771467329.parquet ...
# Reading prc771467890.parquet ...
# Reading prc771468885.parquet ...
# Reading prc771468993.parquet ...
# Reading prc771471206.parquet ...
# Reading prc771473022.parquet ...
# Reading prc771476023.parquet ...
# Reading prc771483546.parquet ...
# Reading prc771484409.parquet ...
# Reading prc771484672.parquet ...
# Reading prc771489661.parquet ...
# Reading prc771491598.parquet ...
# Reading prc771492353.parquet ...
# Reading prc771494375.parquet ...
# Reading prc771494576.parquet ...
# Reading prc771495752.parquet ...
# Reading prc771499741.parquet ...
# Reading prc771501267.parquet ...
# Reading prc771501487.parquet ...
# Reading prc771505293.parquet ...
# Reading prc771509185.parquet ...
# Reading prc771509826.parquet ...
# Reading prc771514881.parquet ...
# Reading prc771515607.parquet ...
# Reading prc771515935.parquet ...
# Reading prc771518791.parquet ...
# Reading prc771520338.parquet ...
# Reading prc771522171.parquet ...
# Reading prc771523325.parquet ...
# Reading prc771523956.parquet ...
# Reading prc771527033.parquet ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 167
#     163     plot_extra_helpful(df_all)
#     166 if __name__ == "__main__":
# --> 167     main()
#
# Cell In[1], line 146, in main()
#     144 def main():
#     145     # 1) load and merge all parquet files
# --> 146     df_all = load_all_parquet(DATA_DIR)
#     148     # quick numeric summary
#     149     print("\n=== Summary statistics ===")
#
# Cell In[1], line 38, in load_all_parquet(dir_path)
#      35         print(f"  -> skipping {f.name}, missing columns: {missing}")
#      36         continue
# ---> 38     df = df[COLUMNS].copy()
#      39     dfs.append(df)
#      41 if not dfs:
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\frame.py:4128, in DataFrame.__getitem__(self, key)
#    4125 if isinstance(indexer, slice):
#    4126     return self._slice(indexer, axis=1)
# -> 4128 data = self._take_with_is_copy(indexer, axis=1)
#    4130 if is_single_key:
#    4131     # What does looking for a single key in a non-unique index return?
#    4132     # The behavior is inconsistent. It returns a Series, except when
#    4133     # - the key itself is repeated (test on data.shape, #9519), or
#    4134     # - we have a MultiIndex on columns (test on self.columns, #21309)
#    4135     if data.shape[1] == 1 and not isinstance(self.columns, MultiIndex):
#    4136         # GH#26490 using data[key] can cause RecursionError
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\generic.py:4175, in NDFrame._take_with_is_copy(self, indices, axis)
#    4164 @final
#    4165 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4166     """
#    4167     Internal version of the `take` method that sets the `_is_copy`
#    4168     attribute to keep track of the parent dataframe (using in indexing
#    (...)   4173     See the docstring of `take` for full explanation of the parameters.
#    4174     """
# -> 4175     result = self.take(indices=indices, axis=axis)
#    4176     # Maybe set copy if we didn't actually change the index.
#    4177     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\generic.py:4155, in NDFrame.take(self, indices, axis, **kwargs)
#    4150     # We can get here with a slice via DataFrame.__getitem__
#    4151     indices = np.arange(
#    4152         indices.start, indices.stop, indices.step, dtype=np.intp
#    4153     )
# -> 4155 new_data = self._mgr.take(
#    4156     indices,
#    4157     axis=self._get_block_manager_axis(axis),
#    4158     verify=True,
#    4159 )
#    4160 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4161     self, method="take"
#    4162 )
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\internals\managers.py:913, in BaseBlockManager.take(self, indexer, axis, verify)
#     910 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     912 new_labels = self.axes[axis].take(indexer)
# --> 913 return self.reindex_indexer(
#     914     new_axis=new_labels,
#     915     indexer=indexer,
#     916     axis=axis,
#     917     allow_dups=True,
#     918     copy=None,
#     919 )
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\internals\managers.py:699, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     696     raise IndexError("Requested axis not found in manager")
#     698 if axis == 0:
# --> 699     new_blocks = self._slice_take_blocks_ax0(
#     700         indexer,
#     701         fill_value=fill_value,
#     702         only_slice=only_slice,
#     703         use_na_proxy=use_na_proxy,
#     704     )
#     705 else:
#     706     new_blocks = [
#     707         blk.take_nd(
#     708             indexer,
#    (...)    714         for blk in self.blocks
#     715     ]
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\internals\managers.py:862, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy, ref_inplace_op)
#     860                     blocks.append(nb)
#     861             else:
# --> 862                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     863                 blocks.append(nb)
#     865 return blocks
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\internals\blocks.py:1373, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1370     allow_fill = True
#    1372 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1373 new_values = algos.take_nd(
#    1374     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1375 )
#    1377 # Called from three places in managers, all of which satisfy
#    1378 #  these assertions
#    1379 if isinstance(self, ExtensionBlock):
#    1380     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1381     #  algos.take_nd call above.
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File C:\Arbeit\11. Events\12. PRC_Data_Challenge_2025\Code\.venv1\Lib\site-packages\pandas\core\array_algos\take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:
